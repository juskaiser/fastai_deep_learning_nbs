# %%
from __future__ import division,print_function

import os, json
from glob import glob
import numpy as np
np.set_printoptions(precision=4, linewidth=100)
from matplotlib import pyplot as plt

% matplotlib inline

# %%
# Custom utilities
import utils; reload(utils)
from utils import plots
# Out:
# Using Theano backend.

# %%
# setup full path and sample path for testing
# path = 'data/dogscats/'  # Full set
path = 'data/dogscats/sample/'  # Sample set

# %%
# Setup my batch size 64, is best if machiene can handle it otherwise smaller
batch_size=64

# %%
# Import pretrained image nn
import vgg16; reload(vgg16)
from vgg16 import Vgg16

# %%
# instantiate
vgg = Vgg16()

# %%
batches = vgg.get_batches(path+'train', batch_size=4)
# Out:
# Found 16 images belonging to 2 classes.

# %%
img,labels = next(batches)

# %%
plots(img, titles=labels)

# %%
vgg.predict(img, True)
# Out:
# (array([ 0.1152,  0.7001,  0.1634,  0.1022], dtype=float32),
#  array([227, 281, 234, 728]),
#  [u'kelpie', u'tabby', u'Rottweiler', u'plastic_bag'])

# %% [markdown]
# ### Now fine tune the existing NN

# %%
batch_size=64

# %%
batches = vgg.get_batches(path+)
val_batches
